# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy
import flylib as flb
from flylib import util
import pandas as pd

# %%
print flb.__file__
# Out:
# /home/imager/catkin/src/flylib_new_horizons/flylib/flylib/__init__.pyc

# %%
#fly = flb.NetFly(1540) #1389, 1402
fly = flb.NetFly(1402)
# fly = flb.NetFly(1548,rootpath='/home/annie/work/programming/fly_muscle_data/')
fly.open_signals()

# %%
fly.construct_dataframe()
# Out:
# Making dataframe for fly number 1402
#                 t             stimulus      amp_diff  fly_num   pr_left  \
# 0        0.000000  pretrial_stripe_fix -1.317854e-02     1402  0.708540
# 1        0.020000  pretrial_stripe_fix -1.186069e-01     1402  0.680180
# 2        0.040001  pretrial_stripe_fix -1.186069e-01     1402  0.680180
# 3        0.060001  pretrial_stripe_fix -1.186069e-01     1402  0.682898
# 4        0.080002  pretrial_stripe_fix  1.976781e-02     1402  0.686562
# 5        0.100002  pretrial_stripe_fix  1.976781e-02     1402  0.686562
# 6        0.120003  pretrial_stripe_fix -2.635708e-02     1402  0.688008
# 7        0.140003  pretrial_stripe_fix -2.635708e-02     1402  0.688008
# 8        0.160004  pretrial_stripe_fix -2.635708e-02     1402  0.679146
# 9        0.180004  pretrial_stripe_fix  5.271417e-02     1402  0.679146
# 10       0.200005  pretrial_stripe_fix  5.271417e-02     1402  0.688377
# 11       0.220005  pretrial_stripe_fix  5.271417e-02     1402  0.688377
# 12       0.240006  pretrial_stripe_fix -2.635708e-02     1402  0.686331
# 13       0.260006  pretrial_stripe_fix -2.635708e-02     1402  0.694009
# 14       0.280007  pretrial_stripe_fix -1.449640e-01     1402  0.694009
# 15       0.300007  pretrial_stripe_fix -1.449640e-01     1402  0.682879
# 16       0.320008  pretrial_stripe_fix -1.449640e-01     1402  0.682879
# 17       0.340008  pretrial_stripe_fix  2.635708e-02     1402  0.668076
# 18       0.360009  pretrial_stripe_fix  2.635708e-02     1402  0.668076
# 19       0.380009  pretrial_stripe_fix  2.635708e-02     1402  0.680611
# 20       0.400010  pretrial_stripe_fix -1.317854e-02     1402  0.680611
# 21       0.420010  pretrial_stripe_fix -1.317854e-02     1402  0.672688
# 22       0.440011  pretrial_stripe_fix -1.317854e-02     1402  0.672688
# 23       0.460011  pretrial_stripe_fix  1.976781e-02     1402  0.669388
# 24       0.480012  pretrial_stripe_fix  1.976781e-02     1402  0.672692
# 25       0.500012  pretrial_stripe_fix -6.589271e-02     1402  0.672692
# 26       0.520013  pretrial_stripe_fix -6.589271e-02     1402  0.697310
# 27       0.540013  pretrial_stripe_fix -6.589271e-02     1402  0.697310
# 28       0.560014  pretrial_stripe_fix  4.440892e-16     1402  0.712146
# 29       0.580014  pretrial_stripe_fix  4.440892e-16     1402  0.712146
# ...           ...                  ...           ...      ...       ...
# 40920  818.419986         trials_ended -4.612490e-02     1402  1.048023
# 40921  818.439986         trials_ended -4.612490e-02     1402  0.979841
# 40922  818.459987         trials_ended -4.612490e-02     1402  0.979841
# 40923  818.479987         trials_ended  6.589271e-03     1402  0.925602
# 40924  818.499988         trials_ended  6.589271e-03     1402  0.925602
# 40942  0.449577  5.930534     0.882617   1.229729
# 40943  0.449577  5.930534     0.882617   1.229729
# 40944  0.439375  5.950293     1.014252   1.335394
# 40945  0.439375  5.950293     1.014252   1.335394
# 40946  0.440349  6.019742     1.128280   1.298243
# 40947  0.440349  6.019742     1.128280   1.298243
# 40948  0.447521  6.107860     1.116488   1.303298
# 40949  0.447521  6.107860     1.116488   1.303298
#
# [40950 rows x 36 columns]

# %%
flydf = pd.DataFrame()

flydf['t'] = fly.time
flydf['stimulus'] = np.array(fly.experimental_block)
flydf['amp_diff'] = np.array(fly.left_amp)-np.array(fly.right_amp)
#flydf['fly'] = 1540*np.ones(np.shape(fly.time))

# %%
for (key,value) in fly.ca_cam_left_model_fits.items():
    flydf[key+'_left'] = value
for (key,value) in fly.ca_cam_right_model_fits.items():
    flydf[key+'_right'] = value

# flydf['ca_pixel_left'] = fly.ca_cam_left #this is really big (obvs)
print(flydf.head())
# Out:
#           t             stimulus  amp_diff   pr_left  tpd_left   nm_left  \
# 0  0.000000  pretrial_stripe_fix -0.013179  0.708540  0.835611  3.570247
# 1  0.020000  pretrial_stripe_fix -0.118607  0.680180  0.828941  3.472891
# 2  0.040001  pretrial_stripe_fix -0.118607  0.680180  0.828941  3.472891
# 3  0.060001  pretrial_stripe_fix -0.118607  0.682898  0.859689  3.431953
# 4  0.080002  pretrial_stripe_fix  0.019768  0.686562  0.852365  3.494937
#
#    iii1_left  iii3_left   i2_left  hg2_left    ...      hg2_right  hg3_right  \
# 0   0.290968   3.363093  0.096858  7.612362    ...       2.411053        0.0
# 1   0.292371   3.321522  0.159018  7.815249    ...       2.213527        0.0
# 2   0.292371   3.321522  0.159018  7.815249    ...       2.213527        0.0
# 3   0.290368   3.468105  0.084371  7.926731    ...       2.540249        0.0
# 4   0.311877   3.466165  0.065525  7.826945    ...       2.382590        0.0
#
#    hg1_right  i1_right  bkg_right  b1_right  b2_right  b3_right  iii24_right  \
# 0   1.908049  0.811761  22.668967  4.710406  0.443592  6.620500     1.417827
# 1   1.990165  0.834270  22.552789  4.717388  0.409753  6.609745     1.592198
# 2   1.990165  0.834270  22.552789  4.717388  0.409753  6.609745     1.592198
# 3   2.007132  0.811398  22.563688  4.697974  0.435059  6.699666     1.522105
# 4   1.997269  0.801805  22.693248  4.720579  0.424732  6.550722     1.515392
#
#    hg4_right
# 0   1.604632
# 1   1.803883
# 2   1.803883
# 3   1.727006
# 4   1.742365
#
# [5 rows x 35 columns]

# %%
pre= flydf.loc[flydf['stimulus'] == 'pretrial_stripe_fix']
pre['t'][1200]
pre['t'][39831]
# Out:
# 796.63945395491953

# %%
flydf.to_csv('df_fly_1402')

# %%
print(flydf.columns.values)
# Out:
# ['t' 'stimulus' 'amp_diff' 'pr_left' 'tpd_left' 'nm_left' 'iii1_left'
#  'iii3_left' 'i2_left' 'hg2_left' 'hg3_left' 'hg1_left' 'i1_left'
#  'bkg_left' 'b1_left' 'b2_left' 'b3_left' 'iii24_left' 'hg4_left'
#  'pr_right' 'tpd_right' 'nm_right' 'iii1_right' 'iii3_right' 'i2_right'
#  'hg2_right' 'hg3_right' 'hg1_right' 'i1_right' 'bkg_right' 'b1_right'
#  'b2_right' 'b3_right' 'iii24_right' 'hg4_right']

# %%
print(np.unique(flydf['stimulus']))
# Out:
# ['cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0'
#  'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0'
#  'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0'
#  'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=0, b_y=0'
#  'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=1, b_y=0'
#  'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=2, b_y=0'
#  'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=3, b_y=0'
#  'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0'
#  'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0'
#  'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0'
#  'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=0, b_y=0'
#  'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=1, b_y=0'
#  'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0'
#  'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=3, b_y=0'
#  'pretrial_stripe_fix' 'trials_ended']

# %%
print(flydf.columns.values)
# Out:
# ['t' 'stimulus' 'amp_diff' 'pr_left' 'tpd_left' 'nm_left' 'iii1_left'
#  'iii3_left' 'i2_left' 'hg2_left' 'hg3_left' 'hg1_left' 'i1_left'
#  'bkg_left' 'b1_left' 'b2_left' 'b3_left' 'iii24_left' 'hg4_left'
#  'pr_right' 'tpd_right' 'nm_right' 'iii1_right' 'iii3_right' 'i2_right'
#  'hg2_right' 'hg3_right' 'hg1_right' 'i1_right' 'bkg_right' 'b1_right'
#  'b2_right' 'b3_right' 'iii24_right' 'hg4_right']

# %%
#Here is an example of how to filter for rows of a certain column value
filtered_df = flydf.loc[flydf['stimulus']=='cl_blocks, g_x=-1, g_y=0, b_x=-8, b_y=0, ch=True']

print(filtered_df.head())
# Out:
# Empty DataFrame
# Columns: [t, stimulus, amp_diff, pr_left, tpd_left, nm_left, iii1_left, iii3_left, i2_left, hg2_left, hg3_left, hg1_left, i1_left, bkg_left, b1_left, b2_left, b3_left, iii24_left, hg4_left, pr_right, tpd_right, nm_right, iii1_right, iii3_right, i2_right, hg2_right, hg3_right, hg1_right, i1_right, bkg_right, b1_right, b2_right, b3_right, iii24_right, hg4_right]
# Index: []
#
# [0 rows x 35 columns]

# %%
#Or for a combination of column values
idx = (flydf['stimulus']=='cl_blocks, g_x=-1, g_y=0, b_x=-8, b_y=0, ch=True')& \
        (flydf['amp_diff']>0.1)

double_filtered_df = flydf.loc[idx]

print(double_filtered_df.head())
# Out:
# Empty DataFrame
# Columns: [t, stimulus, amp_diff, pr_left, tpd_left, nm_left, iii1_left, iii3_left, i2_left, hg2_left, hg3_left, hg1_left, i1_left, bkg_left, b1_left, b2_left, b3_left, iii24_left, hg4_left, pr_right, tpd_right, nm_right, iii1_right, iii3_right, i2_right, hg2_right, hg3_right, hg1_right, i1_right, bkg_right, b1_right, b2_right, b3_right, iii24_right, hg4_right]
# Index: []
#
# [0 rows x 35 columns]

# %%
#Access calcium values for a specific muscle and specific stimulus
pretrial_stripe_fix_b2_right = flydf.loc[
    flydf['stimulus']=='pretrial_stripe_fix',['b2_right']]

print(np.shape(pretrial_stripe_fix_b2_right))

#https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/
# Out:
# (1997, 1)

# %%
flydf['b2_right']
# Out:
# 0        0.443592
# 1        0.409753
# 2        0.409753
# 3        0.435059
# 4        0.424732
# 5        0.424732
# 6        0.430597
# 7        0.430597
# 8        0.405142
# 9        0.405142
# 10       0.405369
# 11       0.405369
# 12       0.421321
# 13       0.439534
# 14       0.439534
# 15       0.433521
# 16       0.433521
# 17       0.423516
# 18       0.423516
# 19       0.428463
# 20       0.428463
# 21       0.435768
# 22       0.435768
# 23       0.389231
# 24       0.417564
# 25       0.417564
# 26       0.396973
# 27       0.396973
# 28       0.439034
# 29       0.439034
#            ...
# 40920    0.424611
# 40921    0.440576
# 40922    0.440576
# 40923    0.433034
# 40924    0.433034
# 40925    0.433034
# 40926    0.444339
# 40927    0.444339
# 40928    0.451630
# 40929    0.451630
# 40930    0.454792
# 40931    0.454792
# 40932    0.449531
# 40933    0.449531
# 40934    0.432657
# 40935    0.432657
# 40936    0.438067
# 40937    0.438067
# 40938    0.447956
# 40939    0.447956
# 40940    0.461013
# 40941    0.461013
# 40942    0.449577
# 40943    0.449577
# 40944    0.439375
# 40945    0.439375
# 40946    0.440349
# 40947    0.440349
# 40948    0.447521
# 40949    0.447521
# Name: b2_right, Length: 40950, dtype: float64

# %%
mean_b2_left = flydf['b2_left']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.44031559554174454

# %%
mean_b2_left = flydf['b2_right']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.42087348843611178

# %%
mean_b2_left = flydf['i1_left']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.60115538770437282

# %%
mean_b2_left = flydf['i1_right']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.81698510981214156

# %%
#### Find all regions where either i1_R, i1L are > thresh, and either b2_R or b2_L > thresh (DVM's not included... nor B1 phase)... 
#### Also look at ampl diff


idx_2 = ((flydf['b2_right']> 0.48))& \
        ((flydf['i1_left']> 0.65))
        #(flydf['amp_diff']>0.1)
        
idx_3 = ((flydf['b2_left']> 0.55))& \
        ((flydf['i1_right']> 0.65))
        #(flydf['amp_diff']>0.1)
        
idx_4 = ((flydf['b2_right']> 0.5))& \
        ((flydf['i1_right']> 0.7))
        #(flydf['amp_diff']>0.1)

idx_5 = ((flydf['b2_left']> 0.55))& \
        ((flydf['i1_left']> 0.65))
        #(flydf['amp_diff']>0.1)

idx_6 = ((flydf['b2_left']> 0.5))& \
        ((flydf['b2_right']> 0.5))
    
idx_7 = ((flydf['i1_left']> 0.85))& \
        ((flydf['i1_right']> 0.85))
    
    
df_ind_2 = flydf.loc[idx_2]
    
df_ind_3 = flydf.loc[idx_3]
    
df_ind_4 = flydf.loc[idx_4]
    
df_ind_5 = flydf.loc[idx_5]

df_ind_6 = flydf.loc[idx_6]

df_ind_7 = flydf.loc[idx_7]

#loc_from_musc_activity_filtered_df = flydf.loc[idx_2, idx_3, idx_4, idx_5]

# %%
df_ind_2['stimulus'].unique()
# Out:
# array(['pretrial_stripe_fix',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'trials_ended'], dtype=object)

# %%
df_ind_3['stimulus'].unique()
# Out:
# array(['cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'pretrial_stripe_fix'], dtype=object)

# %%
df_ind_4['stimulus'].unique()
# Out:
# array(['cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=3, b_y=0',
#        'trials_ended'], dtype=object)

# %%
df_ind_5['stimulus'].unique()
# Out:
# array(['cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0'], dtype=object)

# %%
df_ind_6['stimulus'].unique()
# Out:
# array(['cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=1, b_y=0'], dtype=object)

# %%
df_ind_7['stimulus'].unique()
# Out:
# array(['cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=3, b_y=0'], dtype=object)

# %%
flydf['stimulus'].unique()
# Out:
# array(['pretrial_stripe_fix',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'trials_ended'], dtype=object)

# %%
import bokeh

# %%
from bokeh.core.properties import Instance, String
from bokeh.models import ColumnDataSource, LayoutDOM
from bokeh.io import show
import pandas as pd
import matplotlib as plt


### read in means and output

# %%
yaw_right = flydf.loc[flydf['stimulus']=='cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0']

roll_right = flydf.loc[flydf['stimulus']=='cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=1, b_y=0']

# %%
yaw_right_trunc = yaw_right[1:450]
roll_right_trunc = roll_right[1:450]

# %%
from scipy import stats
import pandas as pd
import numpy as np
import matplotlib
#from neo.io import AxonIO
#import seaborn as sns
import matplotlib.pyplot as plt
import itertools

import numpy as np
import pandas as pd
import bokeh
import bokeh.plotting
import bokeh.io
from bokeh.embed import components

#from bokeh.io import output_notebook, show

from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource

#from bokeh.plotting import figure, show, output_file
from bokeh.models import Band, ColumnDataSource
import pandas as pd
import numpy as np

#bokeh.io.output_notebook()

# %%
p = bokeh.plotting.figure(height=250,
                          width=550,
                          x_axis_label='time (ms)',
                          y_axis_label='Ca2+ Imaging Muscle Activity')

p.line(source=yaw_right_trunc.loc[::2, :],
       x='t',
       y='b2_left',
       #legend='fly',
       line_join='bevel',
       color = 'darkblue')

p.line(source=yaw_right_trunc.loc[::2, :],
       x='t',
       y='i1_right', alpha = 0.95)
       #legend='fly',
       #line_join='bevel')


#p.quad(top=[0.17], bottom=[-.0.5], left=[10000*5/11],
#       right=[10000*6/11], color ="firebrick", alpha=0.2)

bokeh.io.show(p)

# %%
p = bokeh.plotting.figure(height=250,
                          width=550,
                          x_axis_label='time (ms)',
                          y_axis_label='Ca2+ Imaging Muscle Activity')

p.line(source=roll_right_trunc.loc[:,:],
       x='t',
       y='b2_right',
       #legend='fly',
       line_join='bevel',
       color = 'darkblue')

p.line(source=roll_right_trunc.loc[:,:],
       x='t',
       y='i1_left', alpha = 0.95)
       #legend='fly',
       #line_join='bevel')


#p.quad(top=[0.17], bottom=[-.0.5], left=[10000*5/11],
#       right=[10000*6/11], color ="firebrick", alpha=0.2)

bokeh.io.show(p)

# %%
fly_df = pd.read_csv('df_fly_1398')
