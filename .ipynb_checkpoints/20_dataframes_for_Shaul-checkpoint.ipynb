# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy
import flylib as flb
from flylib import util
import pandas as pd
# Out:
# /home/imager/.local/lib/python2.7/site-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
print flb.__file__
# Out:
# /home/imager/catkin/src/flylib_new_horizons/flylib/flylib/__init__.pyc

# %% [markdown]
# fly_nums = range(1706, 1709) + range(1711, 1714) + range (1715, 1719) + range(1719, 1722) + range(1722, 1727) + range(1729, 1730)# +   range(1731, 1732)## last one are the newest trials --
# #figure out whats wrong with kine cam?
# multi_fly_df = util.construct_multi_fly_df(fly_nums)

# %%
#fly = flb.NetFly(1540) #1389, 1402
fly = flb.NetFly(1706)
# fly = flb.NetFly(1548,rootpath='/home/annie/work/programming/fly_muscle_data/')
fly.open_signals()

# %%
fly.construct_dataframe()
# Out:
# Making dataframe for fly number 1706
#                  t             stimulus  amp_diff  left_amp  right_amp  \
# 0         0.000000  pretrial_stripe_fix  0.139235  0.939798   0.800563
# 1         0.020000  pretrial_stripe_fix  0.157396  0.933744   0.776349
# 2         0.040001  pretrial_stripe_fix  0.157396  0.927691   0.770295
# 3         0.060001  pretrial_stripe_fix  0.157396  0.939798   0.782402
# 4         0.080001  pretrial_stripe_fix  0.145288  0.927691   0.782402
# 5         0.100002  pretrial_stripe_fix  0.145288  0.891369   0.746080
# 6         0.120002  pretrial_stripe_fix  0.163449  0.909530   0.746080
# 7         0.140002  pretrial_stripe_fix  0.127127  0.927691   0.800563
# 8         0.160003  pretrial_stripe_fix  0.157396  0.921637   0.764241
# 9         0.180003  pretrial_stripe_fix  0.199771  0.964013   0.764241
# 10        0.200003  pretrial_stripe_fix  0.157396  0.921637   0.764241
# 11        0.220004  pretrial_stripe_fix  0.133181  0.933744   0.800563
# 12        0.240004  pretrial_stripe_fix  0.133181  0.939798   0.806617
# 13        0.260004  pretrial_stripe_fix  0.163449  0.927691   0.764241
# 14        0.280005  pretrial_stripe_fix  0.169503  0.933744   0.764241
# 15        0.300005  pretrial_stripe_fix  0.163449  0.933744   0.770295
# 16        0.320005  pretrial_stripe_fix  0.108966  0.915583   0.806617
# 17        0.340006  pretrial_stripe_fix  0.121074  0.927691   0.806617
# 18        0.360006  pretrial_stripe_fix  0.139235  0.921637   0.782402
# 19        0.380006  pretrial_stripe_fix  0.102912  0.921637   0.818724
# 20        0.400007  pretrial_stripe_fix  0.096859  0.933744   0.836885
# 21        0.420007  pretrial_stripe_fix  0.096859  0.957959   0.861100
# 22        0.440007  pretrial_stripe_fix  0.102912  0.951905   0.848993
# 23        0.460008  pretrial_stripe_fix  0.115020  0.994281   0.879261
# 24        0.480008  pretrial_stripe_fix  0.078698  0.970066   0.891369
# 25        0.500008  pretrial_stripe_fix  0.066590  0.951905   0.885315
# 26        0.520009  pretrial_stripe_fix  0.078698  0.939798   0.861100
# 27        0.540009  pretrial_stripe_fix  0.127127  0.933744   0.806617
# 28        0.560009  pretrial_stripe_fix  0.127127  0.939798   0.812671
# 29        0.580010  pretrial_stripe_fix  0.127127  0.915583   0.788456
# ...            ...                  ...       ...       ...        ...
# 59520  1190.419990         trials_ended -0.036322  1.194052   1.230374
# 59521  1190.439991         trials_ended -0.018161  1.200106   1.218267
# 59522  1190.459991         trials_ended  0.042376  1.248535   1.206160
# 59523  1190.479991         trials_ended  0.012107  1.206160   1.194052
# 59524  1190.499992         trials_ended  0.036322  1.254589   1.218267
# 59525  1190.519992         trials_ended -0.018161  1.181945   1.200106
# 59526  1190.539992         trials_ended -0.042376  1.242482   1.284857
# 59527  1190.559993         trials_ended -0.024215  1.157730   1.181945
# 59528  1190.579993         trials_ended  0.012107  1.230374   1.218267
# 59529  1190.599993         trials_ended -0.036322  1.163784   1.200106
# 59530  1190.619994         trials_ended  0.145288  1.357502   1.212213
# 59531  1190.639994         trials_ended  0.012107  1.187999   1.175891
# 59532  1190.659994         trials_ended  0.000000  1.206160   1.206160
# 59533  1190.679995         trials_ended -0.030268  1.175891   1.206160
# 59534  1190.699995         trials_ended -0.036322  1.169838   1.206160
# 59535  1190.719995         trials_ended -0.024215  1.181945   1.206160
# 59536  1190.739996         trials_ended -0.072644  1.187999   1.260643
# 59537  1190.759996         trials_ended -0.066590  1.169838   1.236428
# 59538  1190.779996         trials_ended  0.108966  1.321180   1.212213
# 59539  1190.799997         trials_ended -0.060537  1.163784   1.224321
# 59540  1190.819997         trials_ended  0.042376  1.248535   1.206160
# 59541  1190.839997         trials_ended -0.036322  1.175891   1.212213
# 59542  1190.859998         trials_ended  0.157396  1.363555   1.206160
# 59543  1190.879998         trials_ended  0.102912  1.321180   1.218267
# 59544  1190.899998         trials_ended -0.078698  1.200106   1.278804
# 59545  1190.919999         trials_ended -0.060537  1.206160   1.266696
# 59546  1190.939999         trials_ended -0.187664  1.163784   1.351448
# 59547  1190.959999         trials_ended -0.042376  1.200106   1.242482
# 59548  1190.980000         trials_ended -0.066590  1.194052   1.260643
# 59549  1191.000000         trials_ended -0.078698  1.187999   1.266696
#
#        fly_num    wbf                   experimental_condition   pr_left  \
# 0         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.571946
# 1         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.664477
# 2         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.618111
# 3         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.586780
# 4         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.619746
# 5         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.687281
# 6         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.594973
# 7         1706  213.5   condition=pretrial_closed_loop;gain=-1  4.630760
# 8         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.635376
# 9         1706  214.0   condition=pretrial_closed_loop;gain=-1  4.650741
# 10        1706  214.0   condition=pretrial_closed_loop;gain=-1  4.602313
# 11        1706  214.0   condition=pretrial_closed_loop;gain=-1  4.602313
# 12        1706  214.5   condition=pretrial_closed_loop;gain=-1  4.577520
# 13        1706  215.0   condition=pretrial_closed_loop;gain=-1  4.558160
# 14        1706  215.0   condition=pretrial_closed_loop;gain=-1  4.615700
# 15        1706  215.0   condition=pretrial_closed_loop;gain=-1  4.701670
# 16        1706  215.5   condition=pretrial_closed_loop;gain=-1  4.814629
# 17        1706  216.0   condition=pretrial_closed_loop;gain=-1  4.952559
# 18        1706  216.0   condition=pretrial_closed_loop;gain=-1  4.792930
# 19        1706  216.0   condition=pretrial_closed_loop;gain=-1  4.749390
# 20        1706  216.5   condition=pretrial_closed_loop;gain=-1  4.816668
# 21        1706  217.0   condition=pretrial_closed_loop;gain=-1  4.784895
# 22        1706  217.5   condition=pretrial_closed_loop;gain=-1  4.774036
# 23        1706  217.5   condition=pretrial_closed_loop;gain=-1  4.774159
# 24        1706  217.5   condition=pretrial_closed_loop;gain=-1  4.698041
# 25        1706  217.5   condition=pretrial_closed_loop;gain=-1  4.672859
# 26        1706  217.5   condition=pretrial_closed_loop;gain=-1  4.595813
# 27        1706  217.0   condition=pretrial_closed_loop;gain=-1  4.597633
# 28        1706  217.0   condition=pretrial_closed_loop;gain=-1  4.668961
# 29        1706  216.5   condition=pretrial_closed_loop;gain=-1  4.546091
# ...        ...    ...                                      ...       ...
# 59520     1706  126.0  condition=posttrial_closed_loop;gain=-1  2.608009
# 59521     1706  126.0  condition=posttrial_closed_loop;gain=-1  2.623993
# 59522     1706  126.0  condition=posttrial_closed_loop;gain=-1  2.623993
# 59523     1706  126.0  condition=posttrial_closed_loop;gain=-1  2.635104
# 59524     1706  126.0  condition=posttrial_closed_loop;gain=-1  2.635104
# 59525     1706  126.0  condition=posttrial_closed_loop;gain=-1  2.607045
# 59526     1706  126.0  condition=posttrial_closed_loop;gain=-1  2.670252
# 59527     1706  125.5  condition=posttrial_closed_loop;gain=-1  2.670252
# 59528     1706  125.5  condition=posttrial_closed_loop;gain=-1  2.753957
# 59529     1706  125.5  condition=posttrial_closed_loop;gain=-1  2.729035
# 59530     1706  125.0  condition=posttrial_closed_loop;gain=-1  2.729035
# 59531     1706  125.0  condition=posttrial_closed_loop;gain=-1  2.701250
# 59532     1706  125.0  condition=posttrial_closed_loop;gain=-1  2.701250
# 59533     1706  125.0  condition=posttrial_closed_loop;gain=-1  2.680208
# 59534     1706  124.5  condition=posttrial_closed_loop;gain=-1  2.696285
# 59535     1706  124.5  condition=posttrial_closed_loop;gain=-1  2.696285
# 59536     1706  124.5  condition=posttrial_closed_loop;gain=-1  2.669326
# 59537     1706  124.5  condition=posttrial_closed_loop;gain=-1  2.669326
# 59538     1706  124.5  condition=posttrial_closed_loop;gain=-1  2.638491
# 59539     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.637988
# 59540     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.637988
# 59541     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.630259
# 59542     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.667726
# 59543     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.667726
# 59544     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.670861
# 59545     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.670861
# 59546     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.738333
# 59547     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.820644
# 59548     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.820644
# 59549     1706  124.0  condition=posttrial_closed_loop;gain=-1  2.775108
#
#        tpd_left    ...      hg2_right  hg3_right  hg1_right  i1_right  \
# 0      1.491414    ...      19.647446   0.000000   3.828224  2.385128
# 1      1.574465    ...      21.139917   0.000000   3.981724  2.436680
# 2      1.586186    ...      20.197371   0.000000   3.817812  2.375776
# 3      1.496374    ...      19.958486   0.000000   3.717019  2.344355
# 4      1.460535    ...      20.540743   0.000000   3.876640  2.395799
# 5      1.514934    ...      20.939475   0.000000   4.089639  2.442334
# 6      1.435459    ...      20.129521   0.000000   3.989033  2.380729
# 7      1.407904    ...      19.587866   0.000000   3.842302  2.361260
# 8      1.519874    ...      19.872443   0.000000   3.748392  2.379935
# 9      1.546784    ...      19.608802   0.000000   3.823788  2.360249
# 10     1.416901    ...      19.569120   0.000000   3.663269  2.347366
# 11     1.416901    ...      19.569120   0.000000   3.663269  2.347366
# 12     1.464632    ...      20.499759   0.000000   3.995945  2.340980
# 13     1.573694    ...      20.667450   0.000000   3.894403  2.333552
# 14     1.557687    ...      20.697831   0.000000   3.875094  2.328425
# 15     1.508775    ...      20.839190   0.000000   3.924392  2.298043
# 16     1.544347    ...      21.216331   0.000000   3.942039  2.324984
# 17     1.550909    ...      21.330106   0.000000   3.882770  2.319588
# 18     1.512490    ...      20.403711   0.000000   3.788175  2.214777
# 19     1.448992    ...      20.691825   0.000000   3.817017  2.220468
# 20     1.550432    ...      21.517289   0.000000   3.861830  2.279756
# 21     1.574090    ...      20.962585   0.000000   3.846093  2.257719
# 22     1.533776    ...      21.180957   0.000000   3.767274  2.266857
# 23     1.542749    ...      20.695815   0.000000   3.703421  2.323098
# 24     1.550820    ...      20.945459   0.000000   3.781028  2.346323
# 25     1.541784    ...      20.188398   0.000000   3.762881  2.371116
# 26     1.500957    ...      20.057632   0.000000   3.616012  2.416963
# 27     1.580349    ...      19.536625   0.000000   3.738030  2.353664
# 28     1.648410    ...      21.095389   0.000000   3.779776  2.437793
# 29     1.610977    ...      20.779247   0.000000   3.889854  2.365146
# ...         ...    ...            ...        ...        ...       ...
# 59520  1.900666    ...      15.827875   0.482328   3.682347  2.216035
# 59521  1.930115    ...      16.019032   0.485295   3.714656  2.213209
# 59522  1.930115    ...      16.019032   0.485295   3.714656  2.213209
# 59523  1.926495    ...      16.002875   0.588678   3.682812  2.192147
# 59524  1.926495    ...      16.002875   0.588678   3.682812  2.192147
# 59525  1.863874    ...      16.430037   0.492407   3.648459  2.173047
# 59526  1.902966    ...      15.961601   0.554933   3.550702  2.129952
# 59527  1.902966    ...      15.961601   0.554933   3.550702  2.129952
# 59528  1.890593    ...      16.541017   0.531660   3.655332  2.200590
# 59529  1.857168    ...      16.441783   0.481899   3.646728  2.121188
# 59530  1.857168    ...      16.441783   0.481899   3.646728  2.121188
# 59531  1.839343    ...      15.779206   0.502077   3.688509  2.162303
# 59532  1.839343    ...      15.779206   0.502077   3.688509  2.162303
# 59533  1.854762    ...      16.162639   0.474199   3.729196  2.171625
# 59534  1.910536    ...      16.181077   0.512605   3.608701  2.135093
# 59535  1.910536    ...      16.181077   0.512605   3.608701  2.135093
# 59536  1.855613    ...      16.087340   0.464592   3.694703  2.169484
# 59537  1.855613    ...      16.087340   0.464592   3.694703  2.169484
# 59538  1.864135    ...      16.083523   0.541169   3.570450  2.176254
# 59539  1.842741    ...      15.888922   0.468454   3.730717  2.199878
# 59540  1.842741    ...      15.888922   0.468454   3.730717  2.199878
# 59541  1.843536    ...      16.212469   0.530145   3.527934  2.130827
# 59542  1.921232    ...      16.066104   0.546456   3.599501  2.184203
# 59543  1.921232    ...      16.066104   0.546456   3.599501  2.184203
# 59544  1.840289    ...      15.999596   0.502271   3.597808  2.169066
# 59545  1.840289    ...      15.999596   0.502271   3.597808  2.169066
# 59546  1.810315    ...      16.427909   0.428247   3.708976  2.108422
# 59547  1.852644    ...      16.494991   0.460857   3.770178  2.149733
# 59548  1.852644    ...      16.494991   0.460857   3.770178  2.149733
# 59549  1.761925    ...      16.104965   0.433158   3.826464  2.107482
#
#        bkg_right  b1_right  b2_right  b3_right  iii24_right  hg4_right
# 0      52.770800  3.479168  0.262396  5.933876     0.306789   2.824595
# 1      53.675583  3.579196  0.283829  6.072957     0.405268   3.070222
# 2      52.496064  3.496466  0.247891  5.962103     0.496774   2.775119
# 3      52.445010  3.468740  0.256312  6.021583     0.499345   2.914766
# 4      52.481228  3.473287  0.258830  6.113495     0.273425   3.082952
# 5      53.292987  3.527047  0.282237  6.021732     0.047129   3.179997
# 6      52.016457  3.480489  0.239964  5.900282     0.000000   3.115494
# 7      52.498709  3.455024  0.264282  5.987255     0.221871   2.714358
# 8      52.415102  3.494030  0.259019  5.983138     0.387045   2.702574
# 9      52.198146  3.508822  0.249402  5.966625     0.371844   2.736805
# 10     52.061228  3.474589  0.280854  5.737272     0.343862   2.727574
# 11     52.061228  3.474589  0.280854  5.737272     0.343862   2.727574
# 12     52.485368  3.547361  0.313422  5.921690     0.359659   2.776745
# 13     52.362472  3.507666  0.280070  5.648644     0.247651   2.750328
# 14     52.385408  3.485370  0.261913  5.552821     0.517107   2.772666
# 15     52.515497  3.528661  0.264725  5.397211     0.446268   2.697650
# 16     53.711295  3.569544  0.322498  5.254521     0.480558   2.614629
# 17     53.325402  3.541591  0.313103  5.347611     0.486024   2.593225
# 18     52.501172  3.464450  0.313923  4.803287     0.363181   2.514562
# 19     52.652555  3.452260  0.336523  4.866872     0.428903   2.633154
# 20     53.668482  3.540608  0.315024  5.039189     0.516836   2.375462
# 21     52.824979  3.482294  0.271128  4.989550     0.540254   2.537071
# 22     52.771808  3.486698  0.249202  5.159300     0.771161   2.636025
# 23     53.052948  3.483924  0.273740  5.507156     0.637030   2.551737
# 24     52.954482  3.500803  0.261538  5.751422     0.722941   2.572610
# 25     52.846437  3.503675  0.260136  5.964452     0.659472   2.719246
# 26     52.961225  3.457423  0.262735  6.011030     0.455980   2.566378
# 27     52.928233  3.506592  0.260921  5.892134     0.499543   2.496858
# 28     53.753335  3.588091  0.262507  6.065033     0.579860   2.691308
# 29     52.768431  3.499576  0.264036  5.957746     0.438200   3.015571
# ...          ...       ...       ...       ...          ...        ...
# 59520  46.651463  2.465749  0.231330  5.447062     0.000000   1.850395
# 59521  46.655648  2.341762  0.267414  5.475637     0.000000   1.631915
# 59522  46.655648  2.341762  0.267414  5.475637     0.000000   1.631915
# 59523  46.633404  2.404112  0.227143  5.489198     0.000000   1.674729
# 59524  46.633404  2.404112  0.227143  5.489198     0.000000   1.674729
# 59525  46.579175  2.433677  0.249060  5.302772     0.000000   1.645203
# 59526  46.774923  2.470879  0.257726  4.958467     0.000000   1.607861
# 59527  46.774923  2.470879  0.257726  4.958467     0.000000   1.607861
# 59528  47.462559  2.433042  0.254866  5.186576     0.000000   1.507623
# 59529  46.959504  2.407309  0.244051  4.681178     0.000000   1.597503
# 59530  46.959504  2.407309  0.244051  4.681178     0.000000   1.597503
# 59531  46.620471  2.339833  0.241493  4.900052     0.000000   1.618291
# 59532  46.620471  2.339833  0.241493  4.900052     0.000000   1.618291
# 59533  46.704335  2.337441  0.244851  5.118558     0.000000   1.648484
# 59534  46.625336  2.322603  0.248381  5.186356     0.000000   1.661755
# 59535  46.625336  2.322603  0.248381  5.186356     0.000000   1.661755
# 59536  46.732945  2.362324  0.236478  5.247185     0.000000   1.720140
# 59537  46.732945  2.362324  0.236478  5.247185     0.000000   1.720140
# 59538  46.625059  2.325523  0.253243  5.301988     0.000000   1.633898
# 59539  46.488930  2.351722  0.226199  5.305021     0.000000   1.590862
# 59540  46.488930  2.351722  0.226199  5.305021     0.000000   1.590862
# 59541  46.624413  2.392014  0.243350  5.207216     0.000000   1.518703
# 59542  46.961144  2.444230  0.238438  5.398865     0.000000   1.577131
# 59543  46.961144  2.444230  0.238438  5.398865     0.000000   1.577131
# 59544  46.705895  2.479741  0.237507  5.114638     0.000000   1.448853
# 59545  46.705895  2.479741  0.237507  5.114638     0.000000   1.448853
# 59546  47.037515  2.544909  0.239528  4.610688     0.000000   1.612666
# 59547  47.874283  2.647221  0.242712  4.514069     0.000000   1.336995
# 59548  47.874283  2.647221  0.242712  4.514069     0.000000   1.336995
# 59549  47.220553  2.541221  0.245675  4.381925     0.000000   1.442702
#
# [59550 rows x 40 columns]

# %%
flydf = pd.DataFrame()

flydf['t'] = fly.time
flydf['stimulus'] = np.array(fly.experimental_block)
flydf['amp_diff'] = np.array(fly.left_amp)-np.array(fly.right_amp)
flydf['left_amp'] = np.array(fly.left_amp)


#flydf['fly'] = 1540*np.ones(np.shape(fly.time))

# %%
for (key,value) in fly.ca_cam_left_model_fits.items():
    flydf[key+'_left'] = value
for (key,value) in fly.ca_cam_right_model_fits.items():
    flydf[key+'_right'] = value

# flydf['ca_pixel_left'] = fly.ca_cam_left #this is really big (obvs)
print(flydf.head())
# Out:
#           t             stimulus  amp_diff  left_amp   pr_left  tpd_left  \
# 0  0.000000  pretrial_stripe_fix  0.139235  0.939798  4.571946  1.491414
# 1  0.020000  pretrial_stripe_fix  0.157396  0.933744  4.664477  1.574465
# 2  0.040001  pretrial_stripe_fix  0.157396  0.927691  4.618111  1.586186
# 3  0.060001  pretrial_stripe_fix  0.157396  0.939798  4.586780  1.496374
# 4  0.080001  pretrial_stripe_fix  0.145288  0.927691  4.619746  1.460535
#
#     nm_left  iii1_left  iii3_left   i2_left    ...      hg2_right  hg3_right  \
# 0  3.633256   1.243205   5.067034  0.397978    ...      19.647446        0.0
# 1  3.776958   1.256940   5.064494  0.312262    ...      21.139917        0.0
# 2  3.562859   1.219613   4.869518  0.218798    ...      20.197371        0.0
# 3  3.645538   1.219465   4.584050  0.139618    ...      19.958486        0.0
# 4  3.587502   1.225185   4.571597  0.122230    ...      20.540743        0.0
#
#    hg1_right  i1_right  bkg_right  b1_right  b2_right  b3_right  iii24_right  \
# 0   3.828224  2.385128  52.770800  3.479168  0.262396  5.933876     0.306789
# 1   3.981724  2.436680  53.675583  3.579196  0.283829  6.072957     0.405268
# 2   3.817812  2.375776  52.496064  3.496466  0.247891  5.962103     0.496774
# 3   3.717019  2.344355  52.445010  3.468740  0.256312  6.021583     0.499345
# 4   3.876640  2.395799  52.481228  3.473287  0.258830  6.113495     0.273425
#
#    hg4_right
# 0   2.824595
# 1   3.070222
# 2   2.775119
# 3   2.914766
# 4   3.082952
#
# [5 rows x 36 columns]

# %% [markdown]
# pre= flydf.loc[flydf['stimulus'] == 'pretrial_stripe_fix']
# pre['t'][1200]
# pre['t'][39831]

# %%
flydf.to_csv('df_fly_1706')

# %%
print(flydf.columns.values)
# Out:
# ['t' 'stimulus' 'amp_diff' 'left_amp' 'pr_left' 'tpd_left' 'nm_left'
#  'iii1_left' 'iii3_left' 'i2_left' 'hg2_left' 'hg3_left' 'hg1_left'
#  'i1_left' 'bkg_left' 'b1_left' 'b2_left' 'b3_left' 'iii24_left' 'hg4_left'
#  'pr_right' 'tpd_right' 'nm_right' 'iii1_right' 'iii3_right' 'i2_right'
#  'hg2_right' 'hg3_right' 'hg1_right' 'i1_right' 'bkg_right' 'b1_right'
#  'b2_right' 'b3_right' 'iii24_right' 'hg4_right']

# %%
print(np.unique(flydf['stimulus']))
# Out:
# ['exc_cl_starfield, g_x = 1, g_y=0, b_x =0, b_y = 0, ch=0'
#  'pitch_down_actually_roll, g_x=12, g_y=0, b_x=0, b_y=0, ch=0'
#  'pitch_up_actually_roll, g_x=12, g_y=0, b_x=0, b_y=0, ch=0'
#  'pretrial_stripe_fix'
#  'roll_clockwise_actually_pitch, g_x=12, g_y=0, b_x=0, b_y=0, ch=0'
#  'roll_counterclockwise_actually_pitch, g_x=12, g_y=0, b_x=0, b_y=0, ch=0'
#  'trials_ended' 'yaw_left, g_x=12, g_y=0, b_x=0, b_y=0, ch=0'
#  'yaw_right, g_x=12, g_y=0, b_x=0, b_y=0, ch=0']

# %%
print(flydf.columns.values)
# Out:
# ['t' 'stimulus' 'amp_diff' 'left_amp' 'pr_left' 'tpd_left' 'nm_left'
#  'iii1_left' 'iii3_left' 'i2_left' 'hg2_left' 'hg3_left' 'hg1_left'
#  'i1_left' 'bkg_left' 'b1_left' 'b2_left' 'b3_left' 'iii24_left' 'hg4_left'
#  'pr_right' 'tpd_right' 'nm_right' 'iii1_right' 'iii3_right' 'i2_right'
#  'hg2_right' 'hg3_right' 'hg1_right' 'i1_right' 'bkg_right' 'b1_right'
#  'b2_right' 'b3_right' 'iii24_right' 'hg4_right']

# %%
#Here is an example of how to filter for rows of a certain column value
filtered_df = flydf.loc[flydf['stimulus']=='cl_blocks, g_x=-1, g_y=0, b_x=-8, b_y=0, ch=True']

print(filtered_df.head())
# Out:
# Empty DataFrame
# Columns: [t, stimulus, amp_diff, left_amp, pr_left, tpd_left, nm_left, iii1_left, iii3_left, i2_left, hg2_left, hg3_left, hg1_left, i1_left, bkg_left, b1_left, b2_left, b3_left, iii24_left, hg4_left, pr_right, tpd_right, nm_right, iii1_right, iii3_right, i2_right, hg2_right, hg3_right, hg1_right, i1_right, bkg_right, b1_right, b2_right, b3_right, iii24_right, hg4_right]
# Index: []
#
# [0 rows x 36 columns]

# %%
#Or for a combination of column values
idx = (flydf['stimulus']=='cl_blocks, g_x=-1, g_y=0, b_x=-8, b_y=0, ch=True')& \
        (flydf['amp_diff']>0.1)

double_filtered_df = flydf.loc[idx]

print(double_filtered_df.head())
# Out:
# Empty DataFrame
# Columns: [t, stimulus, amp_diff, left_amp, pr_left, tpd_left, nm_left, iii1_left, iii3_left, i2_left, hg2_left, hg3_left, hg1_left, i1_left, bkg_left, b1_left, b2_left, b3_left, iii24_left, hg4_left, pr_right, tpd_right, nm_right, iii1_right, iii3_right, i2_right, hg2_right, hg3_right, hg1_right, i1_right, bkg_right, b1_right, b2_right, b3_right, iii24_right, hg4_right]
# Index: []
#
# [0 rows x 36 columns]

# %%
#Access calcium values for a specific muscle and specific stimulus
pretrial_stripe_fix_b2_right = flydf.loc[
    flydf['stimulus']=='pretrial_stripe_fix',['b2_right']]

print(np.shape(pretrial_stripe_fix_b2_right))

#https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/
# Out:
# (1951, 1)

# %%
flydf['b2_right']
# Out:
# 0        0.262396
# 1        0.283829
# 2        0.247891
# 3        0.256312
# 4        0.258830
# 5        0.282237
# 6        0.239964
# 7        0.264282
# 8        0.259019
# 9        0.249402
# 10       0.280854
# 11       0.280854
# 12       0.313422
# 13       0.280070
# 14       0.261913
# 15       0.264725
# 16       0.322498
# 17       0.313103
# 18       0.313923
# 19       0.336523
# 20       0.315024
# 21       0.271128
# 22       0.249202
# 23       0.273740
# 24       0.261538
# 25       0.260136
# 26       0.262735
# 27       0.260921
# 28       0.262507
# 29       0.264036
#            ...
# 59520    0.231330
# 59521    0.267414
# 59522    0.267414
# 59523    0.227143
# 59524    0.227143
# 59525    0.249060
# 59526    0.257726
# 59527    0.257726
# 59528    0.254866
# 59529    0.244051
# 59530    0.244051
# 59531    0.241493
# 59532    0.241493
# 59533    0.244851
# 59534    0.248381
# 59535    0.248381
# 59536    0.236478
# 59537    0.236478
# 59538    0.253243
# 59539    0.226199
# 59540    0.226199
# 59541    0.243350
# 59542    0.238438
# 59543    0.238438
# 59544    0.237507
# 59545    0.237507
# 59546    0.239528
# 59547    0.242712
# 59548    0.242712
# 59549    0.245675
# Name: b2_right, Length: 59550, dtype: float64

# %%
mean_b2_left = flydf['b2_left']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.44031559554174454

# %%
mean_b2_left = flydf['b2_right']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.42087348843611178

# %%
mean_b2_left = flydf['i1_left']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.60115538770437282

# %%
mean_b2_left = flydf['i1_right']
mean_b2_left =np.mean(mean_b2_left)
mean_b2_left
# Out:
# 0.81698510981214156

# %%
#### Find all regions where either i1_R, i1L are > thresh, and either b2_R or b2_L > thresh (DVM's not included... nor B1 phase)... 
#### Also look at ampl diff


idx_2 = ((flydf['b2_right']> 0.48))& \
        ((flydf['i1_left']> 0.65))
        #(flydf['amp_diff']>0.1)
        
idx_3 = ((flydf['b2_left']> 0.55))& \
        ((flydf['i1_right']> 0.65))
        #(flydf['amp_diff']>0.1)
        
idx_4 = ((flydf['b2_right']> 0.5))& \
        ((flydf['i1_right']> 0.7))
        #(flydf['amp_diff']>0.1)

idx_5 = ((flydf['b2_left']> 0.55))& \
        ((flydf['i1_left']> 0.65))
        #(flydf['amp_diff']>0.1)

idx_6 = ((flydf['b2_left']> 0.5))& \
        ((flydf['b2_right']> 0.5))
    
idx_7 = ((flydf['i1_left']> 0.85))& \
        ((flydf['i1_right']> 0.85))
    
    
df_ind_2 = flydf.loc[idx_2]
    
df_ind_3 = flydf.loc[idx_3]
    
df_ind_4 = flydf.loc[idx_4]
    
df_ind_5 = flydf.loc[idx_5]

df_ind_6 = flydf.loc[idx_6]

df_ind_7 = flydf.loc[idx_7]

#loc_from_musc_activity_filtered_df = flydf.loc[idx_2, idx_3, idx_4, idx_5]

# %%
df_ind_2['stimulus'].unique()
# Out:
# array(['pretrial_stripe_fix',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'trials_ended'], dtype=object)

# %%
df_ind_3['stimulus'].unique()
# Out:
# array(['cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'pretrial_stripe_fix'], dtype=object)

# %%
df_ind_4['stimulus'].unique()
# Out:
# array(['cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=3, b_y=0',
#        'trials_ended'], dtype=object)

# %%
df_ind_5['stimulus'].unique()
# Out:
# array(['cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0'], dtype=object)

# %%
df_ind_6['stimulus'].unique()
# Out:
# array(['cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=1, b_y=0'], dtype=object)

# %%
df_ind_7['stimulus'].unique()
# Out:
# array(['cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=3, b_y=0'], dtype=object)

# %%
flydf['stimulus'].unique()
# Out:
# array(['pretrial_stripe_fix',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-3, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0',
#        'cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=0, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=1, b_y=0',
#        'cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=2, b_y=0',
#        'trials_ended'], dtype=object)

# %%
import bokeh

# %%
from bokeh.core.properties import Instance, String
from bokeh.models import ColumnDataSource, LayoutDOM
from bokeh.io import show
import pandas as pd
import matplotlib as plt


### read in means and output

# %%
yaw_right = flydf.loc[flydf['stimulus']=='cl_starfield_yaw_blocks, g_x=-2, g_y=0 b_x=-2, b_y=0']

roll_right = flydf.loc[flydf['stimulus']=='cl_starfield_roll_blocks, g_x=-2, g_y=0 b_x=1, b_y=0']

# %%
yaw_right_trunc = yaw_right[1:450]
roll_right_trunc = roll_right[1:450]

# %%
from scipy import stats
import pandas as pd
import numpy as np
import matplotlib
#from neo.io import AxonIO
#import seaborn as sns
import matplotlib.pyplot as plt
import itertools

import numpy as np
import pandas as pd
import bokeh
import bokeh.plotting
import bokeh.io
from bokeh.embed import components

#from bokeh.io import output_notebook, show

from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource

#from bokeh.plotting import figure, show, output_file
from bokeh.models import Band, ColumnDataSource
import pandas as pd
import numpy as np

#bokeh.io.output_notebook()

# %%
p = bokeh.plotting.figure(height=250,
                          width=550,
                          x_axis_label='time (ms)',
                          y_axis_label='Ca2+ Imaging Muscle Activity')

p.line(source=yaw_right_trunc.loc[::2, :],
       x='t',
       y='b2_left',
       #legend='fly',
       line_join='bevel',
       color = 'darkblue')

p.line(source=yaw_right_trunc.loc[::2, :],
       x='t',
       y='i1_right', alpha = 0.95)
       #legend='fly',
       #line_join='bevel')


#p.quad(top=[0.17], bottom=[-.0.5], left=[10000*5/11],
#       right=[10000*6/11], color ="firebrick", alpha=0.2)

bokeh.io.show(p)

# %%
p = bokeh.plotting.figure(height=250,
                          width=550,
                          x_axis_label='time (ms)',
                          y_axis_label='Ca2+ Imaging Muscle Activity')

p.line(source=roll_right_trunc.loc[:,:],
       x='t',
       y='b2_right',
       #legend='fly',
       line_join='bevel',
       color = 'darkblue')

p.line(source=roll_right_trunc.loc[:,:],
       x='t',
       y='i1_left', alpha = 0.95)
       #legend='fly',
       #line_join='bevel')


#p.quad(top=[0.17], bottom=[-.0.5], left=[10000*5/11],
#       right=[10000*6/11], color ="firebrick", alpha=0.2)

bokeh.io.show(p)

# %%
fly_df = pd.read_csv('df_fly_1398')
